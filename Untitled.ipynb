# %%
# from matplotlib import image as mpimg
import matplotlib.image as mpimg # import the built-in function from matplotlib
import matplotlib.pyplot as plt
import numpy as np

img_array = mpimg.imread("photo1.jpg") # convert from image to numpy array
print(img_array.shape)
print(img_array.size)
print(img_array.ndim)
#print(img_array)
plt.imshow(img_array)
# plt.axis('off')
plt.show()
# Out:
# (636, 560, 3)
# 1068480
# 3
