# %% [markdown]
# **The Scenario:** The company database crashed, and the backup data is a mess. You must clean the "Orders" dataset.
# - Handling Missing Data: The dataset is riddled with NaNs. You must use .dropna() to remove rows completely missing an Order ID, .fillna() to replace missing shipping states and transaction with "Unknown" that were lost during export.

# %%
import pandas as pd
df = pd.read_csv("ecommerce.csv")

df_drop_subset = df.dropna(subset=["id"])
df["Shipping State"] = df["shipping state"].fillna("Unknown")
df["trx"] = df["trx"].fillna("Unknown")
print(df_drop_subset)
# Out:
#          id        customer name                        email purchase date  \
# 1     689.0         kimmy haborn          khabornj4@google.es       pending
# 2     414.0    matthias calcutt       mcalcuttbh@freewebs.com    11/17/2025
# 3     789.0    ALGERNON NIAVES     aniaveslw@wunderground.com    2025-09-20
# 5     760.0       hayes kleewein  hkleeweinl3@kickstarter.com    2025-12-30
# 6      97.0    SUSANNE CUMMINS          scummins2o@paypal.com       unknown
# ...     ...                  ...                          ...           ...
# 1092  872.0       shawn hengoed         shengoedo7@ustream.tv       pending
# 1093   88.0     maridel rogeron          mrogeron2f@google.de       unknown
# 1094  331.0     britteny euesden    beuesden96@mayoclinic.com       pending
# 1095  467.0   ALLISTER MELLOWS           amellowscy@vimeo.com    2025-11-06
# 1096  122.0          carl lamey              clamey3d@php.net   17 Mar 2025
#
#         price                                   trx shipping state
# 1     $539.17                                   NaN         Panama
# 2     $534.17  4a22264d-4c87-4f9d-b4a5-99e343cb768e         Brazil
# 3     $345.84  83a9aa51-0a17-4fd8-a7c3-46a87c019f7b    Philippines
# 5     $275.30  f91b1691-2e28-486d-82eb-1a81cba02f98        Germany
# 6     $602.31                                   NaN        Vietnam
# ...       ...                                   ...            ...
# 1092  $179.86  506a5235-eec5-493e-ab86-392840d8dd9b          China
# 1093  $380.12  0da184d0-4c09-4d6b-8d54-cc0f0980fa0e            NaN
# 1094  $699.39  37d4d2d8-06e9-4304-aa87-cecb84d30a95           Peru
# 1095  $127.81  7dac3d2e-cfce-423b-b34c-24c1efa35950            NaN
# 1096  $500.37  a900e75e-5035-4357-824e-d82f8db6a607        Armenia
#
# [930 rows x 7 columns]

# %% [markdown]
# - Handling Duplicates: A glitch caused users to be charged twice. You must use .duplicated() to find identical transactions and .drop_duplicates(keep='first') to refund/remove the errors.

# %%
# print(df)
# print("\n")
duplicates = df[df.duplicated()]
print(f"is duplicates:\n{duplicates}")
df_drop_first = df.drop_duplicates(keep='first')
print(f"is df_drop_first:\n{df_drop_first}")
# Out:
# is duplicates:
#          id         customer name                         email  \
# 83    571.0      drusilla tapply      dtapplyfu@arstechnica.com
# 106   140.0        ralph hobbert   rhobbert3v@deliciousdays.com
# 117     NaN     erinna jeannesson    ejeannessonab@bandcamp.com
# 130    77.0     stormy ingleston    singleston24@vistaprint.com
# 134   219.0     violante tetford         vtetford62@yahoo.co.jp
# ...     ...                   ...                           ...
# 1051  236.0          audy abriani            aabriani6j@nba.com
# 1056  999.0         pete peattie               ppeattierq@is.gd
# 1072    NaN      marianne saynor              msaynor84@nba.com
# 1097    NaN     CYMBRE COCKRILL          ccockrill8b@joomla.org
# 1098    NaN         brynna petrie              bpetriec4@nhs.uk
#
#             purchase date    price                                   trx  \
# 83                pending  $916.37                               Unknown
# 106            03/14/2026  $398.89  c45cc4f2-6254-4431-b32f-e215031013cc
# 117   2025/04/14 01:19:25  $818.34  84058314-7248-4196-90fe-4871b500e702
# 130            08/22/2025  $155.31  c81f0302-fa5c-4d99-bdab-ab40b512a4a1
# 134            12/31/2025  $867.45                               Unknown
# ...                   ...      ...                                   ...
# 1051           2025-09-09  $258.58  38062d13-21c9-440c-aadd-9cbfd90ef0cc
# 1056           2025-08-02  $184.42  c2620440-8f46-4ba4-ba46-5aab43d1b035
# 1072           2025-05-31  $579.85  5c114384-e27b-457e-bdaf-6543a32aaaa3
# 1097          04 Jul 2025  $482.79  98d998ca-0b37-4898-ae25-ab85c4d981db
# 1098          15 Jul 2025  $780.39  39d7652c-fe34-4e66-bf90-b5fb2cfbbf2f
#
#      shipping state Shipping State
# 83              NaN        Unknown
# 106             NaN        Unknown
# 117           China          China
# 130         Ukraine        Ukraine
# 134           Japan          Japan
# ...             ...            ...
# 1051    Philippines    Philippines
# 1056           Peru           Peru
# 1072      Argentina      Argentina
# 1097       Portugal       Portugal
# 1098          China          China
#
# [100 rows x 8 columns]
# is df_drop_first:
#          id         customer name                        email purchase date  \
# 0       NaN        port beckwith     pbeckwith94@geocities.com   30 Jul 2025
# 1     689.0          kimmy haborn          khabornj4@google.es       pending
# 2     414.0     matthias calcutt       mcalcuttbh@freewebs.com    11/17/2025
# 3     789.0     ALGERNON NIAVES     aniaveslw@wunderground.com    2025-09-20
# 4       NaN     kynthia mcquirter  kmcquirter6s@yellowbook.com       unknown
# ...     ...                   ...                          ...           ...
# 1093   88.0      maridel rogeron          mrogeron2f@google.de       unknown
# 1094  331.0      britteny euesden    beuesden96@mayoclinic.com       pending
# 1095  467.0    ALLISTER MELLOWS           amellowscy@vimeo.com    2025-11-06
# 1096  122.0           carl lamey              clamey3d@php.net   17 Mar 2025
# 1099    NaN         tildy worlock        tworlocknw@disqus.com   10 Jan 2026
#
#         price                                   trx shipping state  \
# 0     $460.25  548f8041-6317-4388-8dce-fe6de027505c      Argentina
# 1     $539.17                               Unknown         Panama
# 2     $534.17  4a22264d-4c87-4f9d-b4a5-99e343cb768e         Brazil
# 3     $345.84  83a9aa51-0a17-4fd8-a7c3-46a87c019f7b    Philippines
# 4     $283.29  29c1f562-82cb-40d1-97aa-a467feeb24d8      Indonesia
# ...       ...                                   ...            ...
# 1093  $380.12  0da184d0-4c09-4d6b-8d54-cc0f0980fa0e            NaN
# 1094  $699.39  37d4d2d8-06e9-4304-aa87-cecb84d30a95           Peru
# 1095  $127.81  7dac3d2e-cfce-423b-b34c-24c1efa35950            NaN
# 1096  $500.37  a900e75e-5035-4357-824e-d82f8db6a607        Armenia
# 1099  $173.04  6f79120f-5a4a-4de9-a201-481446647525      Indonesia
#
#      Shipping State
# 0         Argentina
# 1            Panama
# 2            Brazil
# 3       Philippines
# 4         Indonesia
# ...             ...
# 1093        Unknown
# 1094           Peru
# 1095        Unknown
# 1096        Armenia
# 1099      Indonesia
#
# [1000 rows x 8 columns]

# %% [markdown]
# **Data Type Conversions:**
# - "Price" is imported as a string (e.g., "$1,200.50"). You must remove the symbols and use pd.to_numeric() to turn it into a float.

# %%
df["price"] = (df["price"].replace(r"[\$,]", "", regex=True))
df["price"] = pd.to_numeric(df["price"], errors="coerce")
print(df["price"])
# Out:
# 0       460.25
# 1       539.17
# 2       534.17
# 3       345.84
# 4       283.29
#          ...
# 1095    127.81
# 1096    500.37
# 1097    482.79
# 1098    780.39
# 1099    173.04
# Name: price, Length: 1100, dtype: float64

# %% [markdown]
# - Replace the “pending” and “unknown” with the previous datetime

# %%
df["purchase date"] = df["purchase date"].replace(["pending", "unknown"], pd.NA)
print(df["purchase date"])
# Out:
# 0       30 Jul 2025
# 1              <NA>
# 2        11/17/2025
# 3        2025-09-20
# 4              <NA>
#            ...
# 1095     2025-11-06
# 1096    17 Mar 2025
# 1097    04 Jul 2025
# 1098    15 Jul 2025
# 1099    10 Jan 2026
# Name: purchase date, Length: 1100, dtype: object

# %% [markdown]
# - Convert “purchase date" from messy text into a proper datetime object using pd.to_datetime().

# %%
df["purchase date"] = df["purchase date"].fillna(method="ffill")
df["purchase date"] = pd.to_datetime(df["purchase date"], errors="coerce")
print(df["purchase date"])
# Out:
# 0      2025-07-30
# 1      2025-07-30
# 2      2025-07-30
# 3      2025-07-30
# 4      2025-07-30
#           ...
# 1095   2025-05-21
# 1096   2025-03-17
# 1097   2025-07-04
# 1098   2025-07-15
# 1099   2026-01-10
# Name: purchase date, Length: 1100, dtype: datetime64[ns]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_1860\746858904.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["purchase date"] = df["purchase date"].fillna(method="ffill")

# %% [markdown]
# - Convert the “purchase date" format from various format into this format “M/D/Y”

# %%
df["purchase date"] = pd.to_datetime(df["purchase date"], errors="coerce")
df["purchase date"] = df["purchase date"].dt.strftime("%m/%d/%Y")
print(df["purchase date"])
# Out:
# 0       07/30/2025
# 1       07/30/2025
# 2       07/30/2025
# 3       07/30/2025
# 4       07/30/2025
#            ...
# 1095    05/21/2025
# 1096    03/17/2025
# 1097    07/04/2025
# 1098    07/15/2025
# 1099    01/10/2026
# Name: purchase date, Length: 1100, dtype: object

# %% [markdown]
# **String Manipulation:** The "Names" column has chaotic capitalization and extra spaces. You use .str.title() and .str.strip() to fix this. You must also extract the email domain (e.g., extracting "gmail.com" from "user@gmail.com") using .str.split().

# %%
df["customer name"] = df["customer name"].str.strip().str.title()

df["email"] = df["email"].str.split("@").str[-1]

print("\nCleaned Data Preview:\n", df.head())
print("\nData Info:\n")
df.info()

df.to_csv("cleaned_ecommerce.csv", index=False)
# Out:
# Cleaned Data Preview:
#        id      customer name             email purchase date    price  \
# 0    NaN      Port Beckwith     geocities.com   30 Jul 2025  $460.25
# 1  689.0       Kimmy Haborn         google.es       pending  $539.17
# 2  414.0   Matthias Calcutt      freewebs.com    11/17/2025  $534.17
# 3  789.0    Algernon Niaves  wunderground.com    2025-09-20  $345.84
# 4    NaN  Kynthia Mcquirter    yellowbook.com       unknown  $283.29
#
#                                     trx shipping state Shipping State
# 0  548f8041-6317-4388-8dce-fe6de027505c      Argentina      Argentina
# 1                               Unknown         Panama         Panama
# 2  4a22264d-4c87-4f9d-b4a5-99e343cb768e         Brazil         Brazil
# 3  83a9aa51-0a17-4fd8-a7c3-46a87c019f7b    Philippines    Philippines
# 4  29c1f562-82cb-40d1-97aa-a467feeb24d8      Indonesia      Indonesia
#
# Data Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              930 non-null    float64
#  1   customer name   1100 non-null   object
#  2   email           1100 non-null   object
#  3   purchase date   1100 non-null   object
#  4   price           1100 non-null   object
#  5   trx             1100 non-null   object
#  6   shipping state  856 non-null    object
#  7   Shipping State  1100 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 68.9+ KB
