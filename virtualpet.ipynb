# %% [markdown]
# The Goal: Create a Pet class with attributes like name, hunger, energy, and happiness. Create methods like feed(), play(), and sleep() that alter these attributes.
# Concepts Tested: Classes, __init__, self, instance attributes, methods.

# %%
class Pet:
    def __init__(self, name):
       self.name = name
       self.hunger = 50
       self.energy = 50
       self.happiness = 50
    def feed(self):
        self.hunger -= 10
        print(f"{self.name} has been fed. Hunger: {self.hunger} ")
    def play(self):
        self.energy -= 15
        self.hunger += 10
        self.happiness +=15
        print(f"{self.name} is playing. Energy: {self.energy} Hunger: {self.hunger} Happiness {self.happiness}")
       
    def sleep(self):
        print(f"{self.name} is sleepping ")
        self.energy += 30
        self.hungy -= 20
        self.happiness += 25
            
    def status(self):
        print(f"\n{self.name} is Status: ")
        print(f"Hunger: {self.hunger}")
        print(f"Enter energy: {self.energy}")
        print(f"Happiness: {self.happiness}")
   
pet1 = Pet("Lucy")
pet1.feed()
pet1.play()
# Out:
# Lucy has been fed. Hunger: 40
# Lucy is playing. Energy: 35 Hunger: 60 Happiness 65
