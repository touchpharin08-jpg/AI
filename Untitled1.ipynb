# %%
import pandas as pd
import numpy as np
data = {
    'Name': ['Alice', np.nan, 'Charlie', 'Bob'],
    'Age': [25, np.nan, 30, np.nan],
    'Score': [85, 90, np.nan, np.nan]
}
df = pd.DataFrame(data)
print(df)
print("\n")
# fill_age = df['Age'].fillna(0)
# print(fill_age)
fill_name = df['Name'].fillna('Unknown')
print(fill_name)
# mean_score = df['Score'].mean()
# print(f"mean_score is: {mean_score}")
# fill_score_mean = df['Score'].fillna(mean_score)
# print(fill_score_mean)
# df['Name'] = df['Name'].ffill()
# df['Name'] = df['Name'].bfill()
# print(df['Name'])
# Out:
#       Name   Age  Score
# 0    Alice  25.0   85.0
# 1      NaN   NaN   90.0
# 2  Charlie  30.0    NaN
# 3      Bob   NaN    NaN
#
#
# 0      Alice
# 1    Unknown
# 2    Charlie
# 3        Bob
# Name: Name, dtype: object

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Alice', 'Charlie', 'Bob'],
    'Age': [25, 30, 25, 35, 30]
}
df = pd.DataFrame(data)
print(df)
print("\n")
df_drop_first = df.drop_duplicates(keep='first')
print(df_drop_first)

# df_drop_last = df.drop_duplicates(keep='last')
# print(df_drop_last)

# df_drop_none = df.drop_duplicates(keep=False)
# df.drop_duplicates(inplace=True)
# print(df)
# # print(df_drop_none)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2    Alice   25
# 3  Charlie   35
# 4      Bob   30
#
#
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 3  Charlie   35
