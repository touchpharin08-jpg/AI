# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("/mnt/data/9cd58770-9542-46bb-b950-3cffe26c1711.png")

print("Shape:", img.shape)
print("Dimensions:", img.ndim)
print("Data type:", img.dtype)

canvas = np.zeros_like(img)


h, w = img.shape[:2]
crop = img[h//4:h//2, w//4:w//2]


red_channel = img[:, :, 0]


green_mask = img[:, :, 1] > 0.6   

green_screen = img.copy()
green_screen[green_mask] = [1, 1, 1]  


bright = np.clip(img + 0.2, 0, 1)

gamma = 2.2
gamma_corrected = np.power(img, 1/gamma)

vintage = np.sqrt(img)

print("Max pixel:", np.max(img))
print("Min pixel:", np.min(img))
print("Average intensity:", np.mean(img))

mean_rgb = np.mean(img, axis=(0, 1))
print("Mean RGB:", mean_rgb)

plt.figure(figsize=(12, 10))

plt.subplot(3, 3, 1)
plt.title("Original")
plt.imshow(img)
plt.axis("off")

plt.subplot(3, 3, 2)
plt.title("Cropped")
plt.imshow(crop)
plt.axis("off")

plt.subplot(3, 3, 3)
plt.title("Red Channel")
plt.imshow(red_channel, cmap="Reds")
plt.axis("off")

plt.subplot(3, 3, 4)
plt.title("Green Removed")
plt.imshow(green_screen)
plt.axis("off")

plt.subplot(3, 3, 5)
plt.title("Brightened")
plt.imshow(bright)
plt.axis("off")

plt.subplot(3, 3, 6)
plt.title("Gamma Corrected")
plt.imshow(gamma_corrected)
plt.axis("off")

plt.subplot(3, 3, 7)
plt.title("Vintage")
plt.imshow(vintage)
plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
#   Cell In[7], line 5
#     img = mpimg.imread("https://lh3.googleusercontent.com/drive-storage/AJQWtBPEAcIODP3u-henK_vkTXLPfRE_DlQWRpx2wQn34cK6LGkxjxQ8Kceko_WnSmtLe96UTXBzUIzlrVvwWr9u-_c33hlmZO3WC5ieAUi37KFyJr45=w1343-h636?auditContext=forDisplay
#                        ^
# SyntaxError: unterminated string literal (detected at line 5)
